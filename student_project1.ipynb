# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
student_mat = pd.read_csv("student-mat.csv",sep=";")

# %%
student_mat.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
student_por = pd.read_csv("student-por.csv",sep=";")
student_por.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
student_mat.school.value_counts()
# Out:
# GP    349
# MS     46
# Name: school, dtype: int64

# %%
student_mat.sex.value_counts()
# Out:
# F    208
# M    187
# Name: sex, dtype: int64

# %%
student_mat.age.value_counts()
# Out:
# 16    104
# 17     98
# 18     82
# 15     82
# 19     24
# 20      3
# 22      1
# 21      1
# Name: age, dtype: int64

# %%
student_mat.higher.value_counts()
# Out:
# yes    375
# no      20
# Name: higher, dtype: int64

# %%
student_mat.pivot_table(values='school',index='Mjob',aggfunc='count')
# Out:
# Mjob
# at_home      59
# health       34
# other       141
# services    103
# teacher      58
# Name: school, dtype: int64

# %%
student_mat.pivot_table(index='Mjob',aggfunc='count')
# Out:
#           Dalc  Fedu  Fjob   G1   G2   G3  Medu  Pstatus  Walc  absences  \
# Mjob
# at_home     59    59    59   59   59   59    59       59    59        59
# health      34    34    34   34   34   34    34       34    34        34
# other      141   141   141  141  141  141   141      141   141       141
# services   103   103   103  103  103  103   103      103   103       103
# teacher     58    58    58   58   58   58    58       58    58        58
#
#              ...      internet  nursery  paid  reason  romantic  school  \
# Mjob         ...
# at_home      ...            59       59    59      59        59      59
# health       ...            34       34    34      34        34      34
# other        ...           141      141   141     141       141     141
# services     ...           103      103   103     103       103     103
# teacher      ...            58       58    58      58        58      58
#
#           schoolsup  sex  studytime  traveltime
# Mjob
# ...

# %%
student_mat[(student_mat['age']>15) & (student_mat['age']<16)]
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, higher, internet, romantic, famrel, freetime, goout, Dalc, Walc, health, absences, G1, G2, G3]
# Index: []
#
# [0 rows x 33 columns]

# %%
student_mat[(student_mat['age']>15) & (student_mat['age']<17)]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 15      GP   F   16       U     GT3       T     4     4    health     other
# 16      GP   F   16       U     GT3       T     4     4  services  services
# 17      GP   F   16       U     GT3       T     3     3     other     other
# 19      GP   M   16       U     LE3       T     4     3    health     other
# 22      GP   M   16       U     LE3       T     4     2   teacher     other
# 23      GP   M   16       U     LE3       T     2     2     other     other
# 25      GP   F   16       U     GT3       T     2     2  services  services
# 28      GP   M   16       U     LE3       A     3     4  services     other
# ...

# %%
# %matplotlib inline
student_mat.age.plot.hist(bins=30)
plt.title("Distribution of student's ages")
plt.ylabel('count of students')
plt.xlabel('age');

# %%
count = student_mat.groupby('G1').agg({'G1': [np.size]})
count
# Out:
#      G1
#    size
# G1
# 3     1
# 4     1
# 5     7
# 6    24
# 7    37
# 8    41
# 9    31
# 10   51
# 11   39
# 12   35
# 13   33
# 14   30
# 15   24
# 16   22
# 17    8
# 18    8
# 19    3

# %%
count = student_mat.groupby('G2').agg({'G2': [np.size]})
count
# Out:
#      G2
#    size
# G2
# 0    13
# 4     1
# 5    15
# 6    14
# 7    21
# 8    32
# 9    50
# 10   46
# 11   35
# 12   41
# 13   37
# 14   23
# 15   34
# 16   13
# 17    5
# 18   12
# 19    3

# %%
count = student_mat.groupby('G1').agg({'G2': [np.size]})
count
# Out:
#      G2
#    size
# G1
# 3     1
# 4     1
# 5     7
# 6    24
# 7    37
# 8    41
# 9    31
# 10   51
# 11   39
# 12   35
# 13   33
# 14   30
# 15   24
# 16   22
# 17    8
# 18    8
# 19    3

# %%
# %matplotlib inline
student_mat.absences.plot.hist(bins=10)
plt.title("Distribution of student's absences")
plt.ylabel('count of students')
plt.xlabel('absence count');

# %%
data = student_mat.set_index('traveltime')
data
# Out:
#            school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# traveltime
# 2              GP   F   18       U     GT3       A     4     4   at_home
# 1              GP   F   17       U     GT3       T     1     1   at_home
# 1              GP   F   15       U     LE3       T     1     1   at_home
# 1              GP   F   15       U     GT3       T     4     2    health
# 1              GP   F   16       U     GT3       T     3     3     other
# 1              GP   M   16       U     LE3       T     4     3  services
# 1              GP   M   16       U     LE3       T     2     2     other
# 2              GP   F   17       U     GT3       A     4     4     other
# 1              GP   M   15       U     LE3       A     3     2  services
# 1              GP   M   15       U     GT3       T     3     4     other
# 1              GP   F   15       U     GT3       T     4     4   teacher
# 3              GP   F   15       U     GT3       T     2     1  services
# ...

# %%
student_mat[(student_mat['traveltime']>3)]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 61      GP   F   16       U     GT3       T     1     1  services  services
# 108     GP   M   15       R     GT3       T     4     4     other     other
# 134     GP   M   15       R     GT3       T     3     4   at_home   teacher
# 149     GP   M   15       U     LE3       A     2     1  services     other
# 164     GP   M   17       R     LE3       T     1     1     other  services
# 228     GP   M   18       U     LE3       T     2     1   at_home     other
# 327     GP   M   17       R     GT3       T     2     2  services     other
# 375     MS   F   18       R     GT3       T     1     1     other     other
#
#     ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 61  ...      5        5      5     5     5      5        6  10   8  11
# 108 ...      1        3      5     3     5      1        6  10  13  13
# 134 ...      5        3      3     1     1      5        0   9   0   0
# ...

# %%
student_mat[(student_mat['traveltime']>3) & (student_mat['sex']=='F')]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 61      GP   F   16       U     GT3       T     1     1  services  services
# 375     MS   F   18       R     GT3       T     1     1     other     other
#
#     ... famrel freetime  goout  Dalc  Walc health absences  G1 G2  G3
# 61  ...      5        5      5     5     5      5        6  10  8  11
# 375 ...      4        3      2     1     2      4        2   8  8  10
#
# [2 rows x 33 columns]

# %%
student_mat[(student_mat['traveltime']>3) & (student_mat['sex']=='M')]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 108     GP   M   15       R     GT3       T     4     4     other     other
# 134     GP   M   15       R     GT3       T     3     4   at_home   teacher
# 149     GP   M   15       U     LE3       A     2     1  services     other
# 164     GP   M   17       R     LE3       T     1     1     other  services
# 228     GP   M   18       U     LE3       T     2     1   at_home     other
# 327     GP   M   17       R     GT3       T     2     2  services     other
#
#     ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 108 ...      1        3      5     3     5      1        6  10  13  13
# 134 ...      5        3      3     1     1      5        0   9   0   0
# 149 ...      4        5      5     2     5      5        0   8   9  10
# 164 ...      5        3      5     1     5      5        0   5   8   7
# 228 ...      4        3      2     4     5      3       14  10   8   9
# ...

# %%
student_mat[(student_mat['Mjob']=='teacher') & (student_mat['sex']=='F')]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 10      GP   F   15       U     GT3       T     4     4  teacher    health
# 63      GP   F   16       U     GT3       T     4     3  teacher    health
# 65      GP   F   16       U     LE3       T     4     3  teacher  services
# 93      GP   F   16       U     GT3       T     4     2  teacher  services
# 139     GP   F   15       U     GT3       T     4     4  teacher   teacher
# 142     GP   F   15       U     GT3       T     4     4  teacher  services
# 199     GP   F   16       U     LE3       T     4     4  teacher   teacher
# 207     GP   F   16       U     GT3       T     4     3  teacher     other
# 209     GP   F   17       R     GT3       T     4     3  teacher     other
# 224     GP   F   16       U     GT3       T     4     4  teacher  services
# 256     GP   F   17       U     LE3       T     4     2  teacher  services
# ...

# %%
student_mat[(student_mat['Mjob']=='teacher') &(student_mat['Fjob']=='teacher') & (student_mat['sex']=='F')]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob ...  \
# 139     GP   F   15       U     GT3       T     4     4  teacher  teacher ...
# 199     GP   F   16       U     LE3       T     4     4  teacher  teacher ...
# 329     GP   F   17       U     GT3       T     4     4  teacher  teacher ...
#
#     famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 139      4        3      2     1     1      5        0  16  16  15
# 199      4        5      2     1     2      3        0   9   9  10
# 329      4        3      3     1     2      4        4  14  14  14
#
# [3 rows x 33 columns]

# %%
student_mat[(student_mat['Mjob']=='teacher') &(student_mat['Fjob']=='teacher') & (student_mat['sex']=='M')]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob ...  \
# 29      GP   M   16       U     GT3       T     4     4  teacher  teacher ...
# 110     GP   M   15       U     LE3       A     4     4  teacher  teacher ...
# 115     GP   M   16       U     GT3       T     4     4  teacher  teacher ...
# 129     GP   M   16       R     GT3       T     4     4  teacher  teacher ...
# 148     GP   M   16       U     GT3       T     4     4  teacher  teacher ...
# 232     GP   M   17       U     GT3       T     4     4  teacher  teacher ...
# 289     GP   M   18       U     LE3       A     4     4  teacher  teacher ...
# 299     GP   M   18       U     LE3       T     4     4  teacher  teacher ...
# 380     MS   M   18       U     GT3       T     4     4  teacher  teacher ...
#
#     famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 29       4        4      5     5     5      5       16  10  12  11
# ...

# %%
student_mat[(student_mat['higher']=='yes') &(student_mat['famsup']=='yes') & (student_mat['sex']=='F')].head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 1      GP   F   17       U     GT3       T     1     1  at_home     other ...
# 3      GP   F   15       U     GT3       T     4     2   health  services ...
# 4      GP   F   16       U     GT3       T     3     3    other     other ...
# 7      GP   F   17       U     GT3       A     4     4    other   teacher ...
# 10     GP   F   15       U     GT3       T     4     4  teacher    health ...
#
#    famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 1       5        3      3     1     1      3        4   5   5   6
# 3       3        2      2     1     1      5        2  15  14  15
# 4       4        3      2     1     2      5        4   6  10  10
# 7       4        1      4     1     1      1        6   6   5   6
# 10      3        3      3     1     2      2        0  10   8   9
#
# [5 rows x 33 columns]

# %%
student_mat[(student_mat['health']<2) &(student_mat['traveltime']>5) & (student_mat['studytime']<5)].head()
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, higher, internet, romantic, famrel, freetime, goout, Dalc, Walc, health, absences, G1, G2, G3]
# Index: []
#
# [0 rows x 33 columns]

# %%
student_mat[(student_mat['health']<3) ].head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 7      GP   F   17       U     GT3       A     4     4     other   teacher
# 8      GP   M   15       U     LE3       A     3     2  services     other
# 10     GP   F   15       U     GT3       T     4     4   teacher    health
# 15     GP   F   16       U     GT3       T     4     4    health     other
# 16     GP   F   16       U     GT3       T     4     4  services  services
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 7  ...      4        1      4     1     1      1        6   6   5   6
# 8  ...      4        2      2     1     1      1        0  16  18  19
# 10 ...      3        3      3     1     2      2        0  10   8   9
# 15 ...      4        4      4     1     2      2        4  14  14  14
# 16 ...      3        2      3     1     2      2        6  13  14  14
#
# [5 rows x 33 columns]
